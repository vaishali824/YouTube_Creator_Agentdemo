# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/agents-intensive-capstone-project/Hackathon dataset.txt

# %% [markdown]
# # Install Required Packages

# %%
# !pip install groq pillow python-dotenv --quiet
# !pip install openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.3/137.3 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (2.7.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)

# %% [markdown]
# # Import Libraries

# %%
import os
from groq import Groq
from PIL import Image, ImageDraw, ImageFont
import json

# %% [markdown]
# # Set API Key

# %%
GROQ_API_KEY = "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"  # paste key here

client = Groq(api_key=GROQ_API_KEY)

# %%
from groq import Groq
client = Groq(api_key="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")

for m in client.models.list().data:
    print(m.id)
# Out:
# whisper-large-v3-turbo
# meta-llama/llama-prompt-guard-2-86m
# llama-3.1-8b-instant
# playai-tts
# whisper-large-v3
# allam-2-7b
# openai/gpt-oss-120b
# meta-llama/llama-4-maverick-17b-128e-instruct
# openai/gpt-oss-safeguard-20b
# meta-llama/llama-guard-4-12b
# moonshotai/kimi-k2-instruct-0905
# qwen/qwen3-32b
# openai/gpt-oss-20b
# meta-llama/llama-4-scout-17b-16e-instruct
# meta-llama/llama-prompt-guard-2-22m
# groq/compound
# moonshotai/kimi-k2-instruct
# playai-tts-arabic
# groq/compound-mini
# llama-3.3-70b-versatile

# %%
from openai import OpenAI
client = OpenAI(api_key="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")   # <--- paste key

# %% [markdown]
# # LLM Wrapper

# %%
from groq import Groq

client = Groq(api_key="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")

def llm(prompt):
    try:
        completion = client.chat.completions.create(
            model="llama-3.3-70b-versatile",
            messages=[
                {"role": "user", "content": prompt}
            ]
        )
        return completion.choices[0].message.content
    except Exception as e:
        return f"[ERROR] {e}"

# %% [markdown]
# # Generate Video Ideas

# %%
from groq import Groq

client = Groq(api_key="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")

def generate_video_ideas(topic):
    prompt = f"Generate 5 YouTube video ideas about: {topic}"

    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",   # UPDATED MODEL
        messages=[{"role": "user", "content": prompt}]
    )

    return response.choices[0].message.content

print("---- VIDEO IDEAS ----")
print(generate_video_ideas("cooking"))
# Out:
# ---- VIDEO IDEAS ----
# Here are five YouTube video ideas about cooking:
#
# 1. **"5-Minute Meal Challenge: Can I Cook a Delicious Dinner in Under 5 Minutes?"**
#
# In this video, you can challenge yourself to cook a complete meal using a specific ingredient or cooking method within a tight time frame of 5 minutes. You can choose a theme, such as cooking with one pot, using only pantry staples, or making a vegetarian or vegan dish. The video can be fast-paced and entertaining, with a timer counting down as you cook.
#
# 2. **"Cooking with Leftovers: 3 Creative Recipes to Reduce Food Waste"**
#
# This video can focus on reducing food waste by creating delicious meals using leftover ingredients. You can showcase three different recipes that use common leftover ingredients, such as last night's roast chicken, leftover vegetables, or stale bread. The video can include tips on how to store and reuse leftovers, as well as creative ways to repurpose food scraps.
#
# 3. **"A Taste of Travel: Cooking a Traditional Dish from Around the World"**
#
# In this video, you can take your viewers on a culinary journey to a specific country or region, showcasing a traditional dish from that culture. You can choose a dish that is both authentic and accessible, using ingredients that are easily available in most supermarkets. The video can include stories about the history and cultural significance of the dish, as well as tips on how to cook it at home.
#
# 4. **"Kitchen Hacks: 10 Essential Cooking Tips and Tricks to Make Your Life Easier"**
#
# This video can focus on sharing essential cooking tips and tricks that can make a big difference in the kitchen. You can showcase 10 different hacks, such as how to chop vegetables quickly, how to cook the perfect egg, or how to make a flavorful broth from scratch. The video can be informative and engaging, with close-up shots and animations to illustrate each tip.
#
# 5. **"Budget-Friendly Cooking: How to Make a Gourmet Meal for Under $10"**
#
# In this video, you can challenge yourself to create a gourmet meal on a tight budget of $10 or less. You can choose a specific ingredient or theme, such as cooking with seafood or making a vegetarian dish, and showcase how to shop for ingredients and cook a delicious meal without breaking the bank. The video can include tips on how to shop smart, use affordable ingredients, and cook creatively on a budget.
#
# I hope these ideas inspire you to create some engaging and informative cooking content for your YouTube channel!

# %% [markdown]
# # Pick an Idea and Generate Script

# %%
chosen_idea = input("Choose one idea from the above list: ")

script = llm(f"""
Write a YouTube script for this video idea: {chosen_idea}
Keep it engaging, simple, and suitable for beginners.
""")

print("---- SCRIPT ----")
print(script)
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# /tmp/ipykernel_13/2309522827.py in <cell line: 0>()
# ----> 1 chosen_idea = input("Choose one idea from the above list: ")
#       2
#       3 script = llm(f"""
#       4 Write a YouTube script for this video idea: {chosen_idea}
#       5 Keep it engaging, simple, and suitable for beginners.
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1172         """
#    1173         if not self._allow_stdin:
# -> 1174             raise StdinNotImplementedError(
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %% [markdown]
# # SEO Metadata

# %%
seo = llm(f"""
Create SEO metadata for this YouTube video:
Title, Description, 10 Tags, and 5 Hashtags.
Topic: {chosen_idea}
""")

print("---- SEO METADATA ----")
print(seo)

# %% [markdown]
# # Thumbnail Generator (Image Creation)

# %%
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

def create_thumbnail():

    title = input("Enter Title: ")
    subtitle = input("Enter Subtitle: ")

    # Canvas
    W, H = 1280, 720
    img = Image.new("RGB", (W, H), "#1A1448")
    draw = ImageDraw.Draw(img)

    font = ImageFont.load_default()

    # --------------------------
    # FUNCTION: Convert text → big image
    # --------------------------
    def create_big_text(text, scale, color, outline):
        temp = Image.new("RGBA", (600, 150), (0, 0, 0, 0))
        tdraw = ImageDraw.Draw(temp)

        # Outline
        for dx in range(-2, 3):
            for dy in range(-2, 3):
                tdraw.text((20+dx, 20+dy), text, font=font, fill=outline)

        # Fill
        tdraw.text((20, 20), text, font=font, fill=color)

        # Scale UP
        big = temp.resize((temp.width * scale, temp.height * scale), Image.NEAREST)
        return big

    # Create BIG title
    big_title = create_big_text(title.upper(), scale=12, color="white", outline="black")

    # Subtitle
    big_sub = create_big_text(subtitle, scale=8, color="yellow", outline="black")

    # Paste Title
    img.paste(big_title, (60, 60), big_title)

    # Add Emoji (RIGHT SIDE of Title)
    draw.text((60 + big_title.width + 40, 120), "🍲", font=font, fill="white")

    # Paste Subtitle
    img.paste(big_sub, (80, 380), big_sub)

    img.save("thumbnail_food_style.png")
    print("✔ Saved as thumbnail_food_style.png")

    # Show output
    plt.figure(figsize=(12, 6))
    plt.imshow(img)
    plt.axis("off")
    plt.show()

create_thumbnail()

# %% [markdown]
# # Full Pipeline Output

# %%
topic = input("Enter your topic: ")

full_output = {
    "topic": topic,
    "chosen_idea": chosen_idea,
    "script": script,
    "seo_metadata": seo,
    "thumbnail_file": "thumbnail.png"
}

print(json.dumps(full_output, indent=4))

# %% [markdown]
# # Save as JSON File

# %%
with open("youtube_agent_output.json", "w") as f:
    json.dump(full_output, f, indent=4)

print("Saved to youtube_agent_output.json")
